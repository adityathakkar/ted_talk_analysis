# %% [markdown]
# # TED Talks Unsupervised Topic Clustering
# A Clustering Based Method to Extract Topics and Deeper Insights from Ted Talk Transcripts

# %%
# Import libraries 
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs
from sklearn import feature_extraction
import seaborn as sns
import warnings
import matplotlib.pyplot as plt

# Download stopwords
nltk.download('stopwords')

# Configure display
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 30
sns.set()
warnings.filterwarnings('ignore')
plt.ylim(0, 1)

# Configure run
# %matplotlib inline

# %% [markdown]
# ## Import and Clean Data

# %%
# Import data
ted_main = pd.read_csv('ted_main.csv', sep=',')
display(ted_main.head(2))
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...   Climate advocate
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
#
#                          title  \
# 0  Do schools kill creativity?
# 1  Averting the climate crisis
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520

# %%
ted_transcripts = pd.read_csv('transcripts.csv', sep=',')
display(ted_transcripts.head(3))
# Out:
#                                           transcript  \
# 0  Good morning. How are you?(Laughter)It's been ...
# 1  Thank you so much, Chris. And it's truly a gre...
# 2  (Music: "The Sound of Silence," Simon & Garfun...
#
#                                                  url
# 0  https://www.ted.com/talks/ken_robinson_says_sc...
# 1  https://www.ted.com/talks/al_gore_on_averting_...
# 2  https://www.ted.com/talks/david_pogue_says_sim...

# %%
# Join to combine transcript with other data from main ted dataframe
ted = ted_main.merge(ted_transcripts, left_on='url', right_on='url', how='outer')

# Drop anything with NaN,
ted = ted.dropna()

# Clear unneeded larger variable
del ted_main, ted_transcripts

display(ted.head(2))
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...   Climate advocate
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
#
#                          title  \
# 0  Do schools kill creativity?
# 1  Averting the climate crisis
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
#
#                                           transcript
# 0  Good morning. How are you?(Laughter)It's been ...
# 1  Thank you so much, Chris. And it's truly a gre...

# %% [markdown]
# ## Stemming, Stopwords, Tokens

# %%
# Get stopwords and print sample
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords[0:10])
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
# Stemmer
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %% [markdown]
# ## Helper Functions

# %%
def tokenize_stem(text): 
    # Tokenize by sentence, then by word
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # Filter any tokens not containing letters
    for token in tokens: 
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems 

def tokenize(text):
    # First tokenize by sentence, then by word 
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # Filter out any tokens not containing letters 
    for token in tokens: 
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %% [markdown]
# ## Apply Stemmer to Title

# %%
vocab_stemmed = []
vocab_tokenized = [] 

for title in ted['transcript']:
    words_stemmed = tokenize_stem(title)
    vocab_stemmed.extend(words_stemmed)
    
    words_tokenized = tokenize(title)
    vocab_tokenized.extend(words_tokenized)

# %%
vocab_df = pd.DataFrame({'words': vocab_tokenized}, index = vocab_stemmed)

# %% [markdown]
# ## TF-IDF Matrix & Document Similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Define vectorizer params
tfidf_vectorizer = TfidfVectorizer(max_df = 0.80, max_features=200000,
                                  min_df=0.2, stop_words='english',
                                  use_idf=True, tokenizer=tokenize_stem, ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(ted['transcript'])

display(tfidf_matrix.shape)
# Out:
# (2461, 434)

# %%
terms = tfidf_vectorizer.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)
sim_df = pd.DataFrame(cosine_similarity(tfidf_matrix))

# %%
# Sanity check to ensure data isnt duplicate
display(ted.iloc[[0]])
display(ted.iloc[[663]])
display(ted.iloc[[1418]])
display(ted.iloc[[1409]])
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
#
#                          title  \
# 0  Do schools kill creativity?
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
#
#                                           transcript
# 0  Good morning. How are you?(Laughter)It's been ...
#      comments                                        description  duration  \
# 692      1234  In this poignant, funny follow-up to his fable...      1008
#
#        event   film_date  languages  main_speaker  \
# 692  TED2010  1265414400         57  Ken Robinson
#
#                                                 name  num_speaker  \
# 692  Ken Robinson: Bring on the learning revolution!            1
#
#      published_date                                            ratings  \
# 692      1274691960  [{'id': 7, 'name': 'Funny', 'count': 3000}, {'...
#
#                                          related_talks speaker_occupation  \
# 692  [{'id': 66, 'hero': 'https://pe.tedcdn.com/ima...    Author/educator
#
#                                                   tags  \
# 692  ['TED Brain Trust', 'children', 'creativity', ...
#
#                                  title  \
# 692  Bring on the learning revolution!
#
#                                                    url    views  \
# 692  https://www.ted.com/talks/sir_ken_robinson_bri...  7266316
#
#                                             transcript
# 692  I was here four years ago, and I remember, at ...
#       comments                                        description  duration  \
# 1505       634  Sir Ken Robinson outlines 3 principles crucial...      1151
#
#                     event   film_date  languages  main_speaker  \
# 1505  TED Talks Education  1366675200         43  Ken Robinson
#
#                                                    name  num_speaker  \
# 1505  Ken Robinson: How to escape education's death ...            1
#
#       published_date                                            ratings  \
# 1505      1368198532  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks speaker_occupation  \
# 1505  [{'id': 66, 'hero': 'https://pe.tedcdn.com/ima...    Author/educator
#
#                                                    tags  \
# 1505  ['culture', 'education', 'student', 'teaching'...
#
#                                        title  \
# 1505  How to escape education's death valley
#
#                                                     url    views  \
# 1505  https://www.ted.com/talks/ken_robinson_how_to_...  6657858
#
#                                              transcript
# 1505  Thank you very much.I moved to America 12 year...
#       comments                                        description  duration  \
# 1496       632  Rita Pierson, a teacher for 40 years, once hea...       468
#
#                     event   film_date  languages  main_speaker  \
# 1496  TED Talks Education  1367884800         46  Rita Pierson
#
#                                           name  num_speaker  published_date  \
# 1496  Rita Pierson: Every kid needs a champion            1      1367589737
#
#                                                 ratings  \
# 1496  [{'id': 10, 'name': 'Inspiring', 'count': 5946...
#
#                                           related_talks speaker_occupation  \
# 1496  [{'id': 66, 'hero': 'https://pe.tedcdn.com/ima...           Educator
#
#                                                    tags  \
# 1496  ['children', 'education', 'motivation', 'teach...
#
#                            title  \
# 1496  Every kid needs a champion
#
#                                                     url    views  \
# 1496  https://www.ted.com/talks/rita_pierson_every_k...  7469445
#
#                                              transcript
# 1496  I have spent my entire life either at the scho...

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans

# Number was experimented to 8. Anything > 8 yeilds not enough distinction, and < 8, there is still room for... 
# ...distinction within topics 
k_clusters = 8

km = KMeans(n_clusters=k_clusters)
km.fit(tfidf_matrix)
clusters = km.labels_.tolist()

# %%
from sklearn.externals import joblib

# Line below allows us to save our model
joblib.dump(km, 'doc_cluster_transcript.pkl')

# Line below allows us to load a saved model
# km = joblib.load('doc_cluster_transcript.pkl')

clusters = km.labels_.tolist()

# %%
# Aggregate data
talks = {'title': ted['title'],
         'tags': ted['tags'],
         'views': ted['views'],
         'cluster': clusters}

ted_clustered = pd.DataFrame(talks)
# display(ted_clustered)

# %% [markdown]
# ### Interesting Metrics to Explore

# %%
# How many talks in each cluster?
pd.Series(clusters).value_counts()
# Out:
# 3    747
# 1    725
# 0    397
# 2    207
# 5    125
# 7     91
# 4     86
# 6     83
# dtype: int64

# %%
# Average number of views per clusters
grouped = ted_clustered['views'].groupby(ted_clustered['cluster'])

grouped.mean()
# Out:
# cluster
# 0    1.240805e+06
# 1    1.413166e+06
# 2    1.283570e+06
# 3    2.513875e+06
# 4    2.337126e+06
# 5    1.403045e+06
# 6    1.790145e+06
# 7    1.112356e+06
# Name: views, dtype: float64

# %% [markdown]
# Looks like clusters 3 and 4 get the most views by far. We can extract the keywords from these clusters to understand why they get the most views.

# %% [markdown]
# ### Top Terms Per Cluster
# This will give us an idea as to what the main topic of the cluster is

# %%
# Order cluster centers by proximity to origin
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(k_clusters):
    print("Cluster " + str(i) + " words:")
    
    for ind in order_centroids[i, :6]:
        print(vocab_df.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'))
    print('')
    print('')
# Out:
# Cluster 0 words:
# b'country'
# b'government'
# b'percent'
# b'needs'
# b'states'
# b'global'
#
#
# Cluster 1 words:
# b'actually'
# b'designed'
# b'technology'
# b'human'
# b'computer'
# b'data'
#
#
# Cluster 2 words:
# b'water'
# b'planet'
# b'earth'
# b'food'
# b'energy'
# b'life'
#
#
# Cluster 3 words:
# b'laughter'
# b'said'
# b'say'
# b'life'
# b'got'
# b'love'
#
#
# Cluster 4 words:
# b'brain'
# b'actually'
# b'human'
# b'active'
# b'different'
# b'right'
#
#
# Cluster 5 words:
# b'women'
# b'men'
# b'woman'
# b'mother'
# b'said'
# b'story'
#
#
# Cluster 6 words:
# b'music'
# b'play'
# b'sound'
# b'laughter'
# b'thank'
# b'hears'
#
#
# Cluster 7 words:
# b'city'
# b'buildings'
# b'space'
# b'new'
# b'street'
# b'designed'

# %% [markdown]
# We can look at the top clusters: **Cluster 3** has associated with it words such as life, love, and laughter.
# **Cluster 4** has associated with it words such as brain, different and human.
#
# We're now starting to form a picture of what these clusters are about.
